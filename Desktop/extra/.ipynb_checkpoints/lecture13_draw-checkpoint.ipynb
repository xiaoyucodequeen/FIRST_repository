# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
t = np.arange(0.0, 2.0, 0.01)
s = 1 + np.sin(2 * np.pi * t)

# %%
fix, ax = plt.subplots()
ax.plot(t, s)
ax.set(xlabel = 'time(s)', ylabel = 'voltage(mV)',
       title = 'About as simple as it gets, folks')
ax.grid()

# %%
np.random.seed(19680801)
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

n, bins, patches = plt.hist(x, 50, density=True, facecolor='g', alpha=0.75)


plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)

# %%
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
explode = (0, 0.1, 0, 0)

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode = explode, labels = labels, autopct = '%1.1f%%',
        shadow = True, startangle = 90)
ax1.axis('equal')
# Out:
# (np.float64(-1.1998593992474953),
#  np.float64(1.1047438182080052),
#  np.float64(-1.0999843549394943),
#  np.float64(1.0999992549971187))

# %%
x = np.linspace(0, 1, 500)
y = np.sin(4 * np.pi * x) * np.exp(-5 * x)
fig, ax = plt.subplots()

ax.fill(x, y, zorder = 10)
ax.grid(True, zorder = 5)

# %%
t = np.arange(0.01, 20.0, 0.01)
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)

# log y
ax1.semilogy(t, np.exp(-t / 5.0))
ax1.set(title = 'semilogy')
ax1.grid()

# log x
ax2.semilogx(t, np.sin(2 * np.pi * t))
ax2.set(title = 'semilogx')
ax2.grid()

# log x and y axis
ax3.loglog(t, 20 * np.exp(-t / 10.0), basex=2)
ax3.set(title='loglog base 2 on x')
ax3.grid()

# With errorbars: clip non-positive values
# Use new data for plotting
x = 10.0**np.linspace(0.0, 2.0, 20)
y = x**2.0

ax4.set_xscale("log", nonposx='clip')
ax4.set_yscale("log", nonposy='clip')
ax4.set(title='Errorbars go negative')
ax4.errorbar(x, y, xerr=0.1 * x, yerr=5.0 + 0.75 * y)

fig.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 15
#      12 ax2.grid()
#      14 # log x and y axis
# ---> 15 ax3.loglog(t, 20 * np.exp(-t / 10.0), basex=2)
#      16 ax3.set(title='loglog base 2 on x')
#      17 ax3.grid()
#
# File D:\python\Lib\site-packages\matplotlib\axes\_axes.py:1915, in Axes.loglog(self, *args, **kwargs)
#    1872 """
#    1873 Make a plot with log scaling on both the x- and y-axis.
#    1874
#    (...)
#    1910     Objects representing the plotted data.
#    1911 """
#    1912 dx = {k: v for k, v in kwargs.items()
#    1913       if k in ['base', 'subs', 'nonpositive',
#    1914                'basex', 'subsx', 'nonposx']}
# -> 1915 self.set_xscale('log', **dx)
#    1916 dy = {k: v for k, v in kwargs.items()
#    1917       if k in ['base', 'subs', 'nonpositive',
#    1918                'basey', 'subsy', 'nonposy']}
#    1919 self.set_yscale('log', **dy)
#
# File D:\python\Lib\site-packages\matplotlib\axes\_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File D:\python\Lib\site-packages\matplotlib\axis.py:824, in Axis._set_axes_scale(self, value, **kwargs)
#     821 old_default_lims = (self.get_major_locator()
#     822                     .nonsingular(-np.inf, np.inf))
#     823 for ax in self._get_shared_axes():
# --> 824     ax._axis_map[name]._set_scale(value, **kwargs)
#     825     ax._update_transScale()
#     826     ax.stale = True
#
# File D:\python\Lib\site-packages\matplotlib\axis.py:782, in Axis._set_scale(self, value, **kwargs)
#     780 def _set_scale(self, value, **kwargs):
#     781     if not isinstance(value, mscale.ScaleBase):
# --> 782         self._scale = mscale.scale_factory(value, self, **kwargs)
#     783     else:
#     784         self._scale = value
#
# File D:\python\Lib\site-packages\matplotlib\scale.py:717, in scale_factory(scale, axis, **kwargs)
#     708 """
#     709 Return a scale class by name.
#     710
#    (...)
#     714 axis : `~matplotlib.axis.Axis`
#     715 """
#     716 scale_cls = _api.check_getitem(_scale_mapping, scale=scale)
# --> 717 return scale_cls(axis, **kwargs)
#
# TypeError: LogScale.__init__() got an unexpected keyword argument 'basex'

# %%
t = np.arange(0.01, 20.0, 0.01)
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)

# log y
ax1.semilogy(t, np.exp(-t / 5.0))
ax1.set(title = 'semilogy')
ax1.grid()

# log x
ax2.semilogx(t, np.sin(2 * np.pi * t))
ax2.set(title = 'semilogx')
ax2.grid()

# log x and y axis
ax3.loglog(t, 20 * np.exp(-t / 10.0))
ax3.get_xaxis().set_major_formatter(plt.ScalarFormatter())
ax3.get_xaxis().set_minor_formatter(plt.ScalarFormatter())
ax3.get_xaxis().set_base(2)
ax3.set(title='loglog base 2 on x')
ax3.grid()

# With errorbars: clip non-positive values
# Use new data for plotting
x = 10.0**np.linspace(0.0, 2.0, 20)
y = x**2.0

ax4.set_xscale("log", nonposx='clip')
ax4.set_yscale("log", nonposy='clip')
ax4.set(title='Errorbars go negative')
ax4.errorbar(x, y, xerr=0.1 * x, yerr=5.0 + 0.75 * y)

fig.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 18
#      16 ax3.get_xaxis().set_major_formatter(plt.ScalarFormatter())
#      17 ax3.get_xaxis().set_minor_formatter(plt.ScalarFormatter())
# ---> 18 ax3.get_xaxis().set_base(2)
#      19 ax3.set(title='loglog base 2 on x')
#      20 ax3.grid()
#
# AttributeError: 'XAxis' object has no attribute 'set_base'

# %%
a = b = np.arange(0, 3, 0.02)
c = np.exp(a)
d = c[::-1]

fix, ax = plt.subplots()
ax.plot(a, c, 'k--', label = 'Model length')
ax.plot(a, d, 'k:', label = 'Data length')
ax.plot(a, c + d, 'k', label = 'Total message length')

legend = ax.legend(loc = 'upper center', shadow = True, fontsize = 'x-large')

legend.get_frame().set_facecolor('#00FFCC')
